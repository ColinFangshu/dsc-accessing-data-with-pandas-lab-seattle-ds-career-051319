# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a data set which contains information World cup matches. Let's use the pandas commands learned in the previous lecture to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand and explain some key Pandas methods
# * Access DataFrame data by using the label
# * Perform boolean indexing on both Series and DataFrames
# * Use simple selectors for series
# * Set new Series and DataFrame inputs

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `WorldCupMatches.csv` as a dataframe in Pandas

# %%
import pandas as pd

# %%
data = pd.read_csv('WorldCupMatches.csv')
df = pd.DataFrame(data=data)

# %% [markdown]
# ## Common methods and attributes

# %%
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# Use the correct method to look at the first 7 rows of the data set.

# %%
df.head(7)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
df.tail(3)
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee            Assistant 1              Assistant 2  \
# 849     C�neyt �AKIR (TUR)   DURAN Bahattin (TUR)        ONGUN Tarik (TUR)
# 850  HAIMOUDI Djamel (ALG)   ACHIK Redouane (MAR)  ETCHIALI Abdelhak (ALG)
# 851   Nicola RIZZOLI (ITA)  Renato FAVERANI (ITA)     Andrea STEFANI (ITA)
#
#      RoundID    MatchID Home Team Initials Away Team Initials
# 849   255955  300186490                NED                ARG
# 850   255957  300186502                BRA                NED
# 851   255959  300186501                GER                ARG

# %% [markdown]
# Get a concise summary of your data using `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
# Year                    852 non-null int64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null int64
# Away Team Goals         852 non-null int64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null int64
# Half-time Away Goals    852 non-null int64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null int64
# MatchID                 852 non-null int64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
num_of_rows = len(df.index)
print(num_of_rows)
# Out:
# 852

# %%
num_of_cols = len(list(df.columns))
print(num_of_cols)
# Out:
# 20

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
cols_name = df.columns
print(cols_name)
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting dataframe information

# %% [markdown]
# When looking at the dataframe's `.head()`, you might have noticed that the games are structured chronologically in the dataframe.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
third_to_fifth_games = df.iloc[3:6]
third_to_fifth_games.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA
# 5      201     1095                CHI                MEX

# %% [markdown]
# Now, print all the info from game 5-9, but we're only interested to print out the "Home Team Name" and the "Away Team Name",

# %%
smaller_group_of_data = df.loc[5:10,['Home Team Name','Away Team Name']]
smaller_group_of_data.head()
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
in_1950 = df.loc[df['Year']==1950]
in_1950.head()
# Out:
#     Year              Datetime    Stage  \
# 53  1950  24 Jun 1950 - 15:00   Group 1
# 54  1950  25 Jun 1950 - 15:00   Group 2
# 55  1950  25 Jun 1950 - 15:00   Group 2
# 56  1950  25 Jun 1950 - 15:00   Group 3
# 57  1950  25 Jun 1950 - 15:00   Group 1
#
#                                       Stadium             City Home Team Name  \
# 53  Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro          Brazil
# 54  Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro         England
# 55                           Durival de Brito        Curitiba           Spain
# 56                                   Pacaembu       Sao Paulo          Sweden
# 57                              Independencia  Belo Horizonte      Yugoslavia
#
#     Home Team Goals  Away Team Goals Away Team Name Win conditions  \
# 53                4                0         Mexico
# 54                2                0          Chile
# 55                3                1            USA
# 56                3                2          Italy
# 57                3                0    Switzerland
#
#     Attendance  Half-time Home Goals  Half-time Away Goals  \
# 53     81649.0                     1                     0
# 54     29703.0                     1                     0
# 55      9511.0                     0                     1
# 56     36502.0                     2                     1
# 57      7336.0                     0                     0
#
#                      Referee                 Assistant 1  \
# 53       READER George (ENG)    GRIFFITHS Benjamin (WAL)
# 54  VAN DER MEER Karel (NED)        GARDELLI Mario (BRA)
# 55         VIANA Mario (BRA)  DA COSTA VIEIRA Jose (POR)
# 56           LUTZ Jean (SUI)         BERANEK Alois (AUT)
# 57    GALEATI Giovanni (ITA)           EKLIND Ivan (SWE)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 53      MITCHELL George (SCO)      208     1187                BRA
# 54       DAHLNER Gunnar (SWE)      208     1192                ENG
# 55  DE LA SALLE Charles (FRA)      208     1208                ESP
# 56        TEJADA Carlos (MEX)      208     1219                SWE
# 57     DATTILO Generoso (ITA)      208     1230                YUG
#
#    Away Team Initials
# 53                MEX
# 54                CHI
# 55                USA
# 56                ITA
# 57                SUI

# %%
Group_three_in_1950 = in_1950.loc[in_1950['Stage']=='Group 3']
Group_three_in_1950.head(10)
# Out:
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance column for the Group 3 games

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
Group_three_in_1950_att = Group_three_in_1950.loc[Group_three_in_1950['Stage']=='Group 3','Attendance']
Group_three_in_1950_att.head()
# Out:
# 56    36502.0
# 61     7903.0
# 65    25811.0
# Name: Attendance, dtype: float64

# %% [markdown]
# Throughout the entire history of the world cup, How many Home games were played by the Netherlands?

# %%
homG_by_Nether = df.loc[df['Home Team Name']=='Netherlands']
homG_by_Nether.head(10)
print('There are {} home games played by the Netherlands throughout the entire history'.format(len(homG_by_Nether)))
# Out:
# There are 32 home games played by the Netherlands throughout the entire history

# %% [markdown]
# How many games were played by the Netherlands in total?

# %%
Game_by_Nether = df.loc[(df['Home Team Name']=='Netherlands')|(df['Away Team Name']=='Netherlands')]
Game_by_Nether.head()
print('There are {} games played by Netherlands in total'.format(len(Game_by_Nether)))
# Out:
# There are 54 games played by Netherlands in total

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 world cup.

# %%
Game_in_2014 = df.loc[df['Year']==2014]
Game_USA_in_2014 = Game_in_2014.loc[(Game_in_2014['Home Team Name']=='USA')
                                    |(Game_in_2014['Away Team Name']=='USA')]
print('There are {} games the USA played in the 2014 world cup'.format(len(Game_USA_in_2014)))
# Out:
# There are 5 games the USA played in the 2014 world cup

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 world cup.

# %% [markdown]
# Hint 1: as a first step, create a new data set that only contain games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %%
Games_in_1986 = df.loc[df['Year']==1986]
Games_in_1986.head(15)
Games_in_1986_unique = Games_in_1986['Datetime'].unique()
print(len(Games_in_1986_unique))
# Games_in_1986.tail()
print(len(Games_in_1986))
# Out:
# 39
# 52

# %%
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# In the world cup history, how matches had more than 5 goals in total?

# %%
df['Total_Goals'] = df['Home Team Goals']+df['Away Team Goals']
more_than_5 = len(df.loc[df['Total_Goals']>=5])
print('There are {} matches with more than 5 goals in total'.format(more_than_5))
# Out:
# There are 147 matches with more than 5 goals in total

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column "Half-time Goals".

# %%
df['Half_time Goals'] = 'not calculated yet'
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions         ...          Half-time Away Goals  \
# 0                        ...                             0
# 1                        ...                             0
# 2                        ...                             0
# 3                        ...                             0
# 4                        ...                             0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2 RoundID MatchID  Home Team Initials  \
# 0         REGO Gilberto (BRA)     201    1096                 FRA
# 1       WARNKEN Alberto (CHI)     201    1090                 USA
# 2         BALWAY Thomas (FRA)     201    1093                 YUG
# 3    MATEUCCI Francisco (URU)     201    1098                 ROU
# 4  RADULESCU Constantin (ROU)     201    1085                 ARG
#
#    Away Team Initials Total_Goals     Half_time Goals
# 0                 MEX           5  not calculated yet
# 1                 BEL           3  not calculated yet
# 2                 BRA           3  not calculated yet
# 3                 PER           4  not calculated yet
# 4                 FRA           1  not calculated yet
#
# [5 rows x 22 columns]

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
df.loc[df["Home Team Name"].str.contains('Korea'), "Home Team Name" ]
# Out:
# 179         Korea DPR
# 187         Korea DPR
# 374    Korea Republic
# 386    Korea Republic
# 434    Korea Republic
# 444    Korea Republic
# 480    Korea Republic
# 524    Korea Republic
# 593    Korea Republic
# 609    Korea Republic
# 635    Korea Republic
# 642    Korea Republic
# 655    Korea Republic
# 710    Korea Republic
# 753         Korea DPR
# 802    Korea Republic
# 818    Korea Republic
# Name: Home Team Name, dtype: object

# %% [markdown]
# Imagine that for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
df.loc[df['Home Team Name']=='Korea DPR']=='Korea'
df.loc[df['Home Team Name']=='Korea Republic']=='Korea'
df.loc[df['Away Team Name']=='Korea DPR']=='Korea'
df.loc[df['Away Team Name']=='Korea Republic']=='Korea'
df.loc[df['Home Team Initials']=='KOR']=='NSK'
df.loc[df['Home Team Initials']=='PRK']=='NSK'
df.loc[df['Away Team Initials']=='KOR']=='NSK'
df.loc[df['Away Team Initials']=='PRK']=='NSK'
df.head(50)
# Out:
#     Year              Datetime                  Stage  \
# 0   1930  13 Jul 1930 - 15:00                 Group 1
# 1   1930  13 Jul 1930 - 15:00                 Group 4
# 2   1930  14 Jul 1930 - 12:45                 Group 2
# 3   1930  14 Jul 1930 - 14:50                 Group 3
# 4   1930  15 Jul 1930 - 16:00                 Group 1
# 5   1930  16 Jul 1930 - 14:45                 Group 1
# 6   1930  17 Jul 1930 - 12:45                 Group 2
# 7   1930  17 Jul 1930 - 14:45                 Group 4
# 8   1930  18 Jul 1930 - 14:30                 Group 3
# 9   1930  19 Jul 1930 - 12:50                 Group 1
# 10  1930  19 Jul 1930 - 15:00                 Group 1
# 11  1930  20 Jul 1930 - 13:00                 Group 2
# 12  1930  20 Jul 1930 - 15:00                 Group 4
# 13  1930  21 Jul 1930 - 14:50                 Group 3
# 14  1930  22 Jul 1930 - 14:45                 Group 1
# 15  1930  26 Jul 1930 - 14:45             Semi-finals
# 16  1930  27 Jul 1930 - 14:45             Semi-finals
# 17  1930  30 Jul 1930 - 14:15                   Final
# 18  1934  27 May 1934 - 16:30       Preliminary round
# 19  1934  27 May 1934 - 16:30       Preliminary round
# 20  1934  27 May 1934 - 16:30       Preliminary round
# 21  1934  27 May 1934 - 16:30       Preliminary round
# 22  1934  27 May 1934 - 16:30       Preliminary round
# 23  1934  27 May 1934 - 16:30       Preliminary round
# 24  1934  27 May 1934 - 16:30       Preliminary round
# 25  1934  27 May 1934 - 16:30       Preliminary round
# 26  1934  31 May 1934 - 16:30          Quarter-finals
# 27  1934  31 May 1934 - 16:30          Quarter-finals
# 28  1934  31 May 1934 - 16:30          Quarter-finals
# 29  1934  31 May 1934 - 16:30          Quarter-finals
# 30  1934  01 Jun 1934 - 16:30          Quarter-finals
# 31  1934  03 Jun 1934 - 16:30             Semi-finals
# 32  1934  03 Jun 1934 - 16:30             Semi-finals
# 33  1934  07 Jun 1934 - 18:00   Match for third place
# 34  1934  10 Jun 1934 - 17:30                   Final
# 35  1938  04 Jun 1938 - 17:00             First round
# 36  1938  05 Jun 1938 - 17:00             First round
# 37  1938  05 Jun 1938 - 17:00             First round
# 38  1938  05 Jun 1938 - 17:00             First round
# 39  1938  05 Jun 1938 - 17:00             First round
# 40  1938  05 Jun 1938 - 17:30             First round
# 41  1938  05 Jun 1938 - 18:30             First round
# 42  1938  09 Jun 1938 - 18:00             First round
# 43  1938  09 Jun 1938 - 18:00             First round
# 44  1938  12 Jun 1938 - 17:00          Quarter-finals
# 45  1938  12 Jun 1938 - 17:00          Quarter-finals
# 46  1938  12 Jun 1938 - 17:00          Quarter-finals
# 47  1938  12 Jun 1938 - 17:00          Quarter-finals
# 48  1938  14 Jun 1938 - 18:00          Quarter-finals
# 49  1938  16 Jun 1938 - 18:00             Semi-finals
#
#                     Stadium         City  Home Team Name  Home Team Goals  \
# 0                   Pocitos  Montevideo           France                4
# 1            Parque Central  Montevideo              USA                3
# 2            Parque Central  Montevideo       Yugoslavia                2
# 3                   Pocitos  Montevideo          Romania                3
# 4            Parque Central  Montevideo        Argentina                1
# 5            Parque Central  Montevideo            Chile                3
# 6            Parque Central  Montevideo       Yugoslavia                4
# 7            Parque Central  Montevideo              USA                3
# 8        Estadio Centenario  Montevideo          Uruguay                1
# 9        Estadio Centenario  Montevideo            Chile                1
# 10       Estadio Centenario  Montevideo        Argentina                6
# 11       Estadio Centenario  Montevideo           Brazil                4
# 12       Estadio Centenario  Montevideo         Paraguay                1
# 13       Estadio Centenario  Montevideo          Uruguay                4
# 14       Estadio Centenario  Montevideo        Argentina                3
# 15       Estadio Centenario  Montevideo        Argentina                6
# 16       Estadio Centenario  Montevideo          Uruguay                6
# 17       Estadio Centenario  Montevideo          Uruguay                4
# 18  Stadio Benito Mussolini       Turin          Austria                3
# 19        Giorgio Ascarelli      Naples          Hungary                4
# 20                 San Siro       Milan      Switzerland                3
# 21                Littorale     Bologna           Sweden                3
# 22           Giovanni Berta    Florence          Germany                5
# 23           Luigi Ferraris       Genoa            Spain                3
# 24            Nazionale PNF        Rome            Italy                7
# 25                 Littorio     Trieste   Czechoslovakia                2
# 26  Stadio Benito Mussolini       Turin   Czechoslovakia                3
# 27                 San Siro       Milan          Germany                2
# 28           Giovanni Berta    Florence            Italy                1
# 29                Littorale     Bologna          Austria                2
# 30           Giovanni Berta    Florence            Italy                1
# 31                 San Siro       Milan            Italy                1
# 32            Nazionale PNF        Rome   Czechoslovakia                3
# 33        Giorgio Ascarelli      Naples          Germany                3
# 34            Nazionale PNF        Rome            Italy                2
# 35         Parc des Princes       Paris      Switzerland                1
# 36     Velodrome Municipale       Reims          Hungary                6
# 37          Stade Olympique    Colombes           France                3
# 38          Stade Municipal    Toulouse             Cuba                3
# 39          Stade V�lodrome  Marseilles            Italy                2
# 40       Stade de la Meinau  Strasbourg           Brazil                6
# 41              Cavee Verte    Le Havre   Czechoslovakia                3
# 42          Stade Municipal    Toulouse             Cuba                2
# 43         Parc des Princes       Paris      Switzerland                4
# 44    Stade du Parc Lescure    Bordeaux           Brazil                1
# 45          Victor Boucquey       Lille          Hungary                2
# 46              Fort Carree     Antibes           Sweden                8
# 47          Stade Olympique    Colombes            Italy                3
# 48    Stade du Parc Lescure    Bordeaux           Brazil                2
# 49         Parc des Princes       Paris          Hungary                5
#
#     Away Team Goals     Away Team Name                        Win conditions  \
# 0                 1             Mexico
# 1                 0            Belgium
# 2                 1             Brazil
# 3                 1               Peru
# 4                 0             France
# 5                 0             Mexico
# 6                 0            Bolivia
# 7                 0           Paraguay
# 8                 0               Peru
# 9                 0             France
# 10                3             Mexico
# 11                0            Bolivia
# 12                0            Belgium
# 13                0            Romania
# 14                1              Chile
# 15                1                USA
# 16                1         Yugoslavia
# 17                2          Argentina
# 18                2             France         Austria win after extra time
# 19                2              Egypt
# 20                2        Netherlands
# 21                2          Argentina
# 22                2            Belgium
# 23                1             Brazil
# 24                1                USA
# 25                1            Romania
# 26                2        Switzerland
# 27                1             Sweden
# 28                1              Spain
# 29                1            Hungary
# 30                0              Spain
# 31                0            Austria
# 32                1            Germany
# 33                2            Austria
# 34                1     Czechoslovakia           Italy win after extra time
# 35                1            Germany
# 36                0  Dutch East Indies
# 37                1            Belgium
# 38                3            Romania
# 39                1             Norway           Italy win after extra time
# 40                5             Poland          Brazil win after extra time
# 41                0        Netherlands  Czechoslovakia win after extra time
# 42                1            Romania
# 43                2            Germany
# 44                1     Czechoslovakia
# 45                0        Switzerland
# 46                0               Cuba
# 47                1             France
# 48                1     Czechoslovakia
# 49                1             Sweden
#
#            ...          Half-time Away Goals                     Referee  \
# 0          ...                             0      LOMBARDI Domingo (URU)
# 1          ...                             0           MACIAS Jose (ARG)
# 2          ...                             0         TEJADA Anibal (URU)
# 3          ...                             0       WARNKEN Alberto (CHI)
# 4          ...                             0         REGO Gilberto (BRA)
# 5          ...                             0       CRISTOPHE Henry (BEL)
# 6          ...                             0    MATEUCCI Francisco (URU)
# 7          ...                             0           MACIAS Jose (ARG)
# 8          ...                             0         LANGENUS Jean (BEL)
# 9          ...                             0         TEJADA Anibal (URU)
# 10         ...                             1        SAUCEDO Ulises (BOL)
# 11         ...                             0         BALWAY Thomas (FRA)
# 12         ...                             0     VALLARINO Ricardo (URU)
# 13         ...                             0         REGO Gilberto (BRA)
# 14         ...                             1         LANGENUS Jean (BEL)
# 15         ...                             0         LANGENUS Jean (BEL)
# 16         ...                             1         REGO Gilberto (BRA)
# 17         ...                             2         LANGENUS Jean (BEL)
# 18         ...                             0  VAN MOORSEL Johannes (NED)
# 19         ...                             2    BARLASSINA Rinaldo (ITA)
# 20         ...                             1           EKLIND Ivan (SWE)
# 21         ...                             1           BRAUN Eugen (AUT)
# 22         ...                             2      MATTEA Francesco (ITA)
# 23         ...                             0         BIRLEM Alfred (GER)
# 24         ...                             0           MERCET Rene (SUI)
# 25         ...                             1         LANGENUS Jean (BEL)
# 26         ...                             1         BERANEK Alois (AUT)
# 27         ...                             0    BARLASSINA Rinaldo (ITA)
# 28         ...                             0           BAERT Louis (BEL)
# 29         ...                             0      MATTEA Francesco (ITA)
# 30         ...                             0           MERCET Rene (SUI)
# 31         ...                             0           EKLIND Ivan (SWE)
# 32         ...                             0    BARLASSINA Rinaldo (ITA)
# 33         ...                             1        CARRARO Albino (ITA)
# 34         ...                             0           EKLIND Ivan (SWE)
# 35         ...                             0         LANGENUS Jean (BEL)
# 36         ...                             0          CONRIE Roger (FRA)
# 37         ...                             1        WUETHRICH Hans (SUI)
# 38         ...                             0       SCARPI Giuseppe (ITA)
# 39         ...                             0         BERANEK Alois (AUT)
# 40         ...                             0           EKLIND Ivan (SWE)
# 41         ...                             0       LECLERCQ Lucien (FRA)
# 42         ...                             1         BIRLEM Alfred (GER)
# 43         ...                             2           EKLIND Ivan (SWE)
# 44         ...                             0       VON HERTZKA Pal (HUN)
# 45         ...                             0    BARLASSINA Rinaldo (ITA)
# 46         ...                             0          KRIST Gustav (TCH)
# 47         ...                             1           BAERT Louis (BEL)
# 48         ...                             1    CAPDEVILLE Georges (FRA)
# 49         ...                             1       LECLERCQ Lucien (FRA)
#
#                    Assistant 1                 Assistant 2 RoundID MatchID  \
# 0        CRISTOPHE Henry (BEL)         REGO Gilberto (BRA)     201    1096
# 1     MATEUCCI Francisco (URU)       WARNKEN Alberto (CHI)     201    1090
# 2      VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)     201    1093
# 3          LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)     201    1098
# 4         SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)     201    1085
# 5      APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)     201    1095
# 6       LOMBARDI Domingo (URU)       WARNKEN Alberto (CHI)     201    1092
# 7      APHESTEGUY Martin (URU)         TEJADA Anibal (URU)     201    1097
# 8          BALWAY Thomas (FRA)       CRISTOPHE Henry (BEL)     201    1099
# 9       LOMBARDI Domingo (URU)         REGO Gilberto (BRA)     201    1094
# 10      ALONSO Gualberto (URU)  RADULESCU Constantin (ROU)     201    1086
# 11    MATEUCCI Francisco (URU)        VALLEJO Gaspar (MEX)     201    1091
# 12           MACIAS Jose (ARG)      LOMBARDI Domingo (URU)     201    1089
# 13       WARNKEN Alberto (CHI)        SAUCEDO Ulises (BOL)     201    1100
# 14       CRISTOPHE Henry (BEL)        SAUCEDO Ulises (BOL)     201    1084
# 15        VALLEJO Gaspar (MEX)       WARNKEN Alberto (CHI)     202    1088
# 16        SAUCEDO Ulises (BOL)         BALWAY Thomas (FRA)     202    1101
# 17        SAUCEDO Ulises (BOL)       CRISTOPHE Henry (BEL)     405    1087
# 18       CAIRONI Camillo (ITA)           BAERT Louis (BEL)     204    1104
# 19      DATTILO Generoso (ITA)          SASSI Otello (ITA)     204    1119
# 20         BERANEK Alois (AUT)   BONIVENTO Ferruccio (ITA)     204    1133
# 21        CARRARO Albino (ITA)     TURBIANI Giuseppe (ITA)     204    1102
# 22  MELANDRI Ermenegildo (ITA)         BAERT Jacques (FRA)     204    1108
# 23      CARMINATI Ettore (ITA)      IVANCSICS Mihaly (HUN)     204    1111
# 24        ESCARTIN Pedro (ESP)       ZENISEK Bohumil (TCH)     204    1135
# 25       SCARPI Giuseppe (ITA)     SCORZONI Raffaele (ITA)     204    1141
# 26       MOHAMED Youssuf (EGY)         BAERT Jacques (FRA)     418    1143
# 27           MERCET Rene (SUI)  VAN MOORSEL Johannes (NED)     418    1129
# 28       ZENISEK Bohumil (TCH)      IVANCSICS Mihaly (HUN)     418    1122
# 29        ESCARTIN Pedro (ESP)         BIRLEM Alfred (GER)     418    1106
# 30      IVANCSICS Mihaly (HUN)       ZENISEK Bohumil (TCH)     418    1123
# 31           BAERT Louis (BEL)       ZENISEK Bohumil (TCH)    3492    1107
# 32         BERANEK Alois (AUT)        ESCARTIN Pedro (ESP)    3492    1130
# 33       CAIRONI Camillo (ITA)        ESCARTIN Pedro (ESP)    3491    1105
# 34           BAERT Louis (BEL)      IVANCSICS Mihaly (HUN)    3490    1134
# 35          MARENCO Paul (FRA)  VAN MOORSEL Johannes (NED)     206    1165
# 36   DE LA SALLE Charles (FRA)      WEINGARTNER Karl (AUT)     206    1173
# 37          KRIST Gustav (TCH)         BIRLEM Alfred (GER)     206    1146
# 38    VALPREDE Ferdinand (FRA)           MERKCX Jean (FRA)     206    1156
# 39           BOUTOURE D. (FRA)             TREHOU D. (FRA)     206    1179
# 40        POISSANT Louis (FRA)   KISSENBERGER Ernest (FRA)     206    1150
# 41              OLIVE D. (FRA)           SDEZ Victor (FRA)     206    1172
# 42     CAPDEVILLE Pierre (FRA)          MARENCO Paul (FRA)     206    1157
# 43           BAERT Louis (BEL)  VAN MOORSEL Johannes (NED)     206    1166
# 44       SCARPI Giuseppe (ITA)   DE LA SALLE Charles (FRA)     429    1152
# 45         BERANEK Alois (AUT)           BOUTOURE D. (FRA)     429    1175
# 46      WEINGARTNER Karl (AUT)           SDEZ Victor (FRA)     429    1158
# 47        WUETHRICH Hans (SUI)           EKLIND Ivan (SWE)     429    1164
# 48          MARENCO Paul (FRA)   KISSENBERGER Ernest (FRA)     429    1153
# 49  VAN MOORSEL Johannes (NED)       SCARPI Giuseppe (ITA)    3489    1176
#
#     Home Team Initials  Away Team Initials Total_Goals     Half_time Goals
# 0                  FRA                 MEX           5  not calculated yet
# 1                  USA                 BEL           3  not calculated yet
# 2                  YUG                 BRA           3  not calculated yet
# 3                  ROU                 PER           4  not calculated yet
# 4                  ARG                 FRA           1  not calculated yet
# 5                  CHI                 MEX           3  not calculated yet
# 6                  YUG                 BOL           4  not calculated yet
# 7                  USA                 PAR           3  not calculated yet
# 8                  URU                 PER           1  not calculated yet
# 9                  CHI                 FRA           1  not calculated yet
# 10                 ARG                 MEX           9  not calculated yet
# 11                 BRA                 BOL           4  not calculated yet
# 12                 PAR                 BEL           1  not calculated yet
# 13                 URU                 ROU           4  not calculated yet
# 14                 ARG                 CHI           4  not calculated yet
# 15                 ARG                 USA           7  not calculated yet
# 16                 URU                 YUG           7  not calculated yet
# 17                 URU                 ARG           6  not calculated yet
# 18                 AUT                 FRA           5  not calculated yet
# 19                 HUN                 EGY           6  not calculated yet
# 20                 SUI                 NED           5  not calculated yet
# 21                 SWE                 ARG           5  not calculated yet
# 22                 GER                 BEL           7  not calculated yet
# 23                 ESP                 BRA           4  not calculated yet
# 24                 ITA                 USA           8  not calculated yet
# 25                 TCH                 ROU           3  not calculated yet
# 26                 TCH                 SUI           5  not calculated yet
# 27                 GER                 SWE           3  not calculated yet
# 28                 ITA                 ESP           2  not calculated yet
# 29                 AUT                 HUN           3  not calculated yet
# 30                 ITA                 ESP           1  not calculated yet
# 31                 ITA                 AUT           1  not calculated yet
# 32                 TCH                 GER           4  not calculated yet
# 33                 GER                 AUT           5  not calculated yet
# 34                 ITA                 TCH           3  not calculated yet
# 35                 SUI                 GER           2  not calculated yet
# 36                 HUN                 INH           6  not calculated yet
# 37                 FRA                 BEL           4  not calculated yet
# 38                 CUB                 ROU           6  not calculated yet
# 39                 ITA                 NOR           3  not calculated yet
# 40                 BRA                 POL          11  not calculated yet
# 41                 TCH                 NED           3  not calculated yet
# 42                 CUB                 ROU           3  not calculated yet
# 43                 SUI                 GER           6  not calculated yet
# 44                 BRA                 TCH           2  not calculated yet
# 45                 HUN                 SUI           2  not calculated yet
# 46                 SWE                 CUB           8  not calculated yet
# 47                 ITA                 FRA           4  not calculated yet
# 48                 BRA                 TCH           3  not calculated yet
# 49                 HUN                 SWE           6  not calculated yet
#
# [50 rows x 22 columns]

# %% [markdown]
# Make sure to verify your answer!

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to access data within Pandas!
